# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
import sys, getopt
import csv
import pprint
import xmltodict, json
from datetime import datetime
import matplotlib.pyplot as plt
from adjustText import adjust_text

pp = pprint.PrettyPrinter(indent=4)
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['figure.figsize'] = [10, 6]
pd.set_option('display.max_rows', 500)

# %%
def normalise_df(df):
    df_num = df.select_dtypes(include='number')
    df_norm = (df_num-df_num.min())/(df_num.max()-df_num.min())
    df_norm.xg_against = 1 - df_norm.xg_against
    df[df_norm.columns] = df_norm.round(2)
    return df

# %%
def get_fixtures_for_url(url, team):
    res = requests.get(url)
    ## The next two lines get around the issue with comments breaking the parsing.
    comm = re.compile("<!--|-->")
    soup = BeautifulSoup(comm.sub("",res.text),'lxml')
    all_tables = soup.findAll("tbody")
    columns = ["comp", "venue", "possession", "xg_for", "xg_against", "goals_for", "goals_against", "opponent"]
    string_columns = ["comp", "venue", "opponent"]
    fixtures_table = all_tables[1]
    
    pre_df_fixtures = dict()
    features_wanted = columns
    rows_fixtures = fixtures_table.find_all('tr')
    for row in rows_fixtures:
        if(row.find('th',{"scope":"row"}) != None):
            # get date first
            cell = row.find("th",{"data-stat": "date"})
            a = cell.text.strip().encode()
            text=a.decode("utf-8")
            if "date" in pre_df_fixtures:
                pre_df_fixtures["date"].append(text)
            else:
                pre_df_fixtures["date"] = [text]

            for f in features_wanted:
                
                cell = row.find("td",{"data-stat": f})
                a = cell.text.strip().encode()
                text=a.decode("utf-8")
                if(text == ''):
                    text = '0'
                if f not in string_columns:
                    if "(" in text:
                        text = text.split(" ")[0]
                    text = float(text.replace(',',''))

                if f in pre_df_fixtures:
                    pre_df_fixtures[f].append(text)
                else:
                    pre_df_fixtures[f] = [text]
                pre_df_fixtures["team"] = team
    df_fixtures = pd.DataFrame.from_dict(pre_df_fixtures)
    df_fixtures["date"] = pd.to_datetime(df_fixtures["date"])
    df_fixtures = df_fixtures.set_index("date")
    return df_fixtures

# %%
pl_team_map = {
    "Arsenal": {
        "fbref_id": "18bb7c10",
        "fpl_id": 1
    },"Aston-Villa": {
        "fbref_id": "8602292d",
        "fpl_id": 2
    }, "Brentford": {
        "fbref_id": "cd051869",
        "fpl_id": 3
    },"Brighton-and-Hove-Albion": {
        "fbref_id": "d07537b9",
        "fpl_id": 4
    }, "Burnley": {
        "fbref_id": "943e8050",
        "fpl_id": 5
    }, "Chelsea": {
        "fbref_id": "cff3d9bb",
        "fpl_id": 6
    }, "Crystal-Palace": {
        "fbref_id": "47c64c55",
        "fpl_id": 7
    }, "Everton": {
        "fbref_id": "d3fd31cc",
        "fpl_id": 8
    }, "Leeds-United": {
        "fbref_id": "5bfb9659",
        "fpl_id": 10
    }, "Leicester-City": {
        "fbref_id": "a2d435b3",
        "fpl_id": 9
    }, "Liverpool": {
        "fbref_id": "822bd0ba",
        "fpl_id": 11
    }, "Manchester-City": {
        "fbref_id": "b8fd03ef",
        "fpl_id": 12
    }, "Manchester-United": {
        "fbref_id": "19538871",
        "fpl_id": 13
    }, "Newcastle-United": {
        "fbref_id": "b2b47a98",
        "fpl_id": 14
    }, "Norwich-City": {
        "fbref_id": "1c781004",
        "fpl_id": 15
    }, "Southampton": {
        "fbref_id": "33c895d4",
        "fpl_id": 16
    }, "Tottenham-Hotspur": {
        "fbref_id": "361ca564",
        "fpl_id": 17
    }, "Watford": {
        "fbref_id": "2abfe087",
        "fpl_id": 18
    }, "West-Ham-United": {
        "fbref_id": "7c21e445",
        "fpl_id": 19
    }, "Wolverhampton-Wanderers": {
        "fbref_id": "8cec06e1",
        "fpl_id": 20
    }
}

# %%
data_pull = pd.DataFrame()
for team in pl_team_map:
    url = "https://fbref.com/en/squads/{}/{}-Stats".format(pl_team_map[team]["fbref_id"], team)
    print(url)
    try:
        team_fix = get_fixtures_for_url(url, " ".join(team.split('-')))
    except:
        print("Issue finding results for {}".format(team))
    data_pull = pd.concat([data_pull, team_fix])
# Out:
# https://fbref.com/en/squads/18bb7c10/Arsenal-Stats
# https://fbref.com/en/squads/8602292d/Aston-Villa-Stats
# https://fbref.com/en/squads/cd051869/Brentford-Stats
# https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats
# https://fbref.com/en/squads/943e8050/Burnley-Stats
# https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats
# https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats
# https://fbref.com/en/squads/d3fd31cc/Everton-Stats
# https://fbref.com/en/squads/5bfb9659/Leeds-United-Stats
# https://fbref.com/en/squads/a2d435b3/Leicester-City-Stats
# https://fbref.com/en/squads/822bd0ba/Liverpool-Stats
# https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats
# https://fbref.com/en/squads/19538871/Manchester-United-Stats
# https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats
# https://fbref.com/en/squads/1c781004/Norwich-City-Stats
# https://fbref.com/en/squads/33c895d4/Southampton-Stats
# https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats
# https://fbref.com/en/squads/2abfe087/Watford-Stats
# https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats
# https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats

# %%
aggregate_df = data_pull[data_pull.comp == "Premier League"]
aggregate_df = aggregate_df[aggregate_df.possession > 0]

# %%
att_ceil = 2.5
def_ceil = 2.5
aggregate_df.xg_for = aggregate_df.xg_for.apply(lambda diff: diff if np.abs(diff) < att_ceil else att_ceil)
aggregate_df.xg_against = aggregate_df.xg_against.apply(lambda diff: diff if np.abs(diff) < def_ceil else def_ceil)

aggregate_df["xg_diff"] = aggregate_df["xg_for"] - aggregate_df["xg_against"]

# %%
aggregate_df = normalise_df(aggregate_df)

# %%
aggregate_df
# Out:
#                       comp                      team  ...         opponent  xg_diff
# date                                                  ...
# 2021-08-13  Premier League                   Arsenal  ...        Brentford     0.52
# 2021-08-22  Premier League                   Arsenal  ...          Chelsea     0.04
# 2021-08-28  Premier League                   Arsenal  ...  Manchester City     0.00
# 2021-09-11  Premier League                   Arsenal  ...     Norwich City     0.90
# 2021-09-18  Premier League                   Arsenal  ...          Burnley     0.48
# 2021-09-26  Premier League                   Arsenal  ...        Tottenham     0.46
# 2021-10-02  Premier League                   Arsenal  ...         Brighton     0.31
# 2021-10-18  Premier League                   Arsenal  ...   Crystal Palace     0.60
# 2021-10-22  Premier League                   Arsenal  ...      Aston Villa     0.73
# 2021-10-30  Premier League                   Arsenal  ...   Leicester City     0.44
# 2021-11-07  Premier League                   Arsenal  ...          Watford     0.71
# 2021-11-20  Premier League                   Arsenal  ...        Liverpool     0.06
# 2021-11-27  Premier League                   Arsenal  ...    Newcastle Utd     0.88
# 2021-12-02  Premier League                   Arsenal  ...   Manchester Utd     0.42
# 2021-12-06  Premier League                   Arsenal  ...          Everton     0.54
# 2021-12-11  Premier League                   Arsenal  ...      Southampton     0.69
# 2021-12-15  Premier League                   Arsenal  ...         West Ham     0.96
# 2021-12-18  Premier League                   Arsenal  ...     Leeds United     0.69
# 2021-12-26  Premier League                   Arsenal  ...     Norwich City     1.00
# 2022-01-01  Premier League                   Arsenal  ...  Manchester City     0.33
# 2021-08-14  Premier League               Aston Villa  ...          Watford     0.48
# 2021-08-21  Premier League               Aston Villa  ...    Newcastle Utd     0.58
# 2021-08-28  Premier League               Aston Villa  ...        Brentford     0.40
# 2021-09-11  Premier League               Aston Villa  ...          Chelsea     0.58
# 2021-09-18  Premier League               Aston Villa  ...          Everton     0.62
# 2021-09-25  Premier League               Aston Villa  ...   Manchester Utd     0.27
# 2021-10-03  Premier League               Aston Villa  ...        Tottenham     0.38
# 2021-10-16  Premier League               Aston Villa  ...           Wolves     0.31
# 2021-10-22  Premier League               Aston Villa  ...          Arsenal     0.27
# 2021-10-31  Premier League               Aston Villa  ...         West Ham     0.17
# 2021-11-05  Premier League               Aston Villa  ...      Southampton     0.46
# 2021-11-20  Premier League               Aston Villa  ...         Brighton     0.54
# 2021-11-27  Premier League               Aston Villa  ...   Crystal Palace     0.40
# 2021-12-01  Premier League               Aston Villa  ...  Manchester City     0.50
# 2021-12-05  Premier League               Aston Villa  ...   Leicester City     0.62
# 2021-12-11  Premier League               Aston Villa  ...        Liverpool     0.06
# 2021-12-14  Premier League               Aston Villa  ...     Norwich City     0.75
# 2021-12-26  Premier League               Aston Villa  ...          Chelsea     0.10
# 2022-01-02  Premier League               Aston Villa  ...        Brentford     0.62
# 2021-08-13  Premier League                 Brentford  ...          Arsenal     0.48
# 2021-08-21  Premier League                 Brentford  ...   Crystal Palace     0.56
# 2021-08-28  Premier League                 Brentford  ...      Aston Villa     0.60
# 2021-09-11  Premier League                 Brentford  ...         Brighton     0.60
# 2021-09-18  Premier League                 Brentford  ...           Wolves     0.90
# 2021-09-25  Premier League                 Brentford  ...        Liverpool     0.38
# 2021-10-03  Premier League                 Brentford  ...         West Ham     0.48
# 2021-10-16  Premier League                 Brentford  ...          Chelsea     0.77
# 2021-10-24  Premier League                 Brentford  ...   Leicester City     0.44
# 2021-10-30  Premier League                 Brentford  ...          Burnley     0.19
# 2021-11-06  Premier League                 Brentford  ...     Norwich City     0.67
# 2021-11-20  Premier League                 Brentford  ...    Newcastle Utd     0.33
# 2021-11-28  Premier League                 Brentford  ...          Everton     0.56
# 2021-12-02  Premier League                 Brentford  ...        Tottenham     0.06
# 2021-12-05  Premier League                 Brentford  ...     Leeds United     0.46
# 2021-12-10  Premier League                 Brentford  ...          Watford     0.77
# 2021-12-26  Premier League                 Brentford  ...         Brighton     0.50
# 2021-12-29  Premier League                 Brentford  ...  Manchester City     0.40
# 2022-01-02  Premier League                 Brentford  ...      Aston Villa     0.38
# 2021-08-14  Premier League  Brighton and Hove Albion  ...          Burnley     0.56
# 2021-08-21  Premier League  Brighton and Hove Albion  ...          Watford     0.62
# 2021-08-28  Premier League  Brighton and Hove Albion  ...          Everton     0.38
# 2021-09-11  Premier League  Brighton and Hove Albion  ...        Brentford     0.40
# 2021-09-19  Premier League  Brighton and Hove Albion  ...   Leicester City     0.44
# 2021-09-27  Premier League  Brighton and Hove Albion  ...   Crystal Palace     0.33
# 2021-10-02  Premier League  Brighton and Hove Albion  ...          Arsenal     0.69
# 2021-10-16  Premier League  Brighton and Hove Albion  ...     Norwich City     0.48
# 2021-10-23  Premier League  Brighton and Hove Albion  ...  Manchester City     0.25
# 2021-10-30  Premier League  Brighton and Hove Albion  ...        Liverpool     0.50
# 2021-11-06  Premier League  Brighton and Hove Albion  ...    Newcastle Utd     0.79
# 2021-11-20  Premier League  Brighton and Hove Albion  ...      Aston Villa     0.46
# 2021-11-27  Premier League  Brighton and Hove Albion  ...     Leeds United     0.75
# 2021-12-01  Premier League  Brighton and Hove Albion  ...         West Ham     0.40
# 2021-12-04  Premier League  Brighton and Hove Albion  ...      Southampton     0.50
# 2021-12-15  Premier League  Brighton and Hove Albion  ...           Wolves     0.46
# 2021-12-26  Premier League  Brighton and Hove Albion  ...        Brentford     0.50
# 2021-12-29  Premier League  Brighton and Hove Albion  ...          Chelsea     0.46
# 2022-01-02  Premier League  Brighton and Hove Albion  ...          Everton     0.46
# 2021-08-14  Premier League                   Burnley  ...         Brighton     0.44
# 2021-08-21  Premier League                   Burnley  ...        Liverpool     0.12
# 2021-08-29  Premier League                   Burnley  ...     Leeds United     0.48
# 2021-09-13  Premier League                   Burnley  ...          Everton     0.50
# 2021-09-18  Premier League                   Burnley  ...          Arsenal     0.52
# 2021-09-25  Premier League                   Burnley  ...   Leicester City     0.12
# 2021-10-02  Premier League                   Burnley  ...     Norwich City     0.60
# 2021-10-16  Premier League                   Burnley  ...  Manchester City     0.31
# 2021-10-23  Premier League                   Burnley  ...      Southampton     0.31
# 2021-10-30  Premier League                   Burnley  ...        Brentford     0.81
# 2021-11-06  Premier League                   Burnley  ...          Chelsea     0.25
# 2021-11-20  Premier League                   Burnley  ...   Crystal Palace     0.35
# 2021-12-01  Premier League                   Burnley  ...           Wolves     0.40
# 2021-12-04  Premier League                   Burnley  ...    Newcastle Utd     0.38
# 2021-12-12  Premier League                   Burnley  ...         West Ham     0.52
# 2021-12-30  Premier League                   Burnley  ...   Manchester Utd     0.25
# 2022-01-02  Premier League                   Burnley  ...     Leeds United     0.38
# 2021-08-14  Premier League                   Chelsea  ...   Crystal Palace     0.62
# 2021-08-22  Premier League                   Chelsea  ...          Arsenal     0.96
# 2021-08-28  Premier League                   Chelsea  ...        Liverpool     0.15
# 2021-09-11  Premier League                   Chelsea  ...      Aston Villa     0.42
# 2021-09-19  Premier League                   Chelsea  ...        Tottenham     0.75
# 2021-09-25  Premier League                   Chelsea  ...  Manchester City     0.21
# 2021-10-02  Premier League                   Chelsea  ...      Southampton     0.75
# 2021-10-16  Premier League                   Chelsea  ...        Brentford     0.23
# 2021-10-23  Premier League                   Chelsea  ...     Norwich City     0.98
# 2021-10-30  Premier League                   Chelsea  ...    Newcastle Utd     0.88
# 2021-11-06  Premier League                   Chelsea  ...          Burnley     0.75
# 2021-11-20  Premier League                   Chelsea  ...   Leicester City     0.92
# 2021-11-28  Premier League                   Chelsea  ...   Manchester Utd     0.88
# 2021-12-01  Premier League                   Chelsea  ...          Watford     0.56
# 2021-12-04  Premier League                   Chelsea  ...         West Ham     0.38
# 2021-12-11  Premier League                   Chelsea  ...     Leeds United     0.73
# 2021-12-16  Premier League                   Chelsea  ...          Everton     0.94
# 2021-12-19  Premier League                   Chelsea  ...           Wolves     0.60
# 2021-12-26  Premier League                   Chelsea  ...      Aston Villa     0.90
# 2021-12-29  Premier League                   Chelsea  ...         Brighton     0.54
# 2022-01-02  Premier League                   Chelsea  ...        Liverpool     0.50
# 2021-08-14  Premier League            Crystal Palace  ...          Chelsea     0.38
# 2021-08-21  Premier League            Crystal Palace  ...        Brentford     0.44
# 2021-08-28  Premier League            Crystal Palace  ...         West Ham     0.40
# 2021-09-11  Premier League            Crystal Palace  ...        Tottenham     0.98
# 2021-09-18  Premier League            Crystal Palace  ...        Liverpool     0.15
# 2021-09-27  Premier League            Crystal Palace  ...         Brighton     0.67
# 2021-10-03  Premier League            Crystal Palace  ...   Leicester City     0.42
# 2021-10-18  Premier League            Crystal Palace  ...          Arsenal     0.40
# 2021-10-23  Premier League            Crystal Palace  ...    Newcastle Utd     0.77
# 2021-10-30  Premier League            Crystal Palace  ...  Manchester City     0.50
# 2021-11-06  Premier League            Crystal Palace  ...           Wolves     0.88
# 2021-11-20  Premier League            Crystal Palace  ...          Burnley     0.65
# 2021-11-27  Premier League            Crystal Palace  ...      Aston Villa     0.60
# 2021-11-30  Premier League            Crystal Palace  ...     Leeds United     0.35
# 2021-12-05  Premier League            Crystal Palace  ...   Manchester Utd     0.46
# 2021-12-12  Premier League            Crystal Palace  ...          Everton     0.54
# 2021-12-15  Premier League            Crystal Palace  ...      Southampton     0.60
# 2021-12-26  Premier League            Crystal Palace  ...        Tottenham     0.02
# 2021-12-28  Premier League            Crystal Palace  ...     Norwich City     0.67
# 2022-01-01  Premier League            Crystal Palace  ...         West Ham     0.54
# 2021-08-14  Premier League                   Everton  ...      Southampton     0.85
# 2021-08-21  Premier League                   Everton  ...     Leeds United     0.60
# 2021-08-28  Premier League                   Everton  ...         Brighton     0.62
# 2021-09-13  Premier League                   Everton  ...          Burnley     0.50
# 2021-09-18  Premier League                   Everton  ...      Aston Villa     0.38
# 2021-09-25  Premier League                   Everton  ...     Norwich City     0.81
# 2021-10-02  Premier League                   Everton  ...   Manchester Utd     0.54
# 2021-10-17  Premier League                   Everton  ...         West Ham     0.35
# 2021-10-23  Premier League                   Everton  ...          Watford     0.46
# 2021-11-01  Premier League                   Everton  ...           Wolves     0.48
# 2021-11-07  Premier League                   Everton  ...        Tottenham     0.44
# 2021-11-21  Premier League                   Everton  ...  Manchester City     0.08
# 2021-11-28  Premier League                   Everton  ...        Brentford     0.44
# 2021-12-01  Premier League                   Everton  ...        Liverpool     0.19
# 2021-12-06  Premier League                   Everton  ...          Arsenal     0.46
# 2021-12-12  Premier League                   Everton  ...   Crystal Palace     0.46
# 2021-12-16  Premier League                   Everton  ...          Chelsea     0.06
# 2022-01-02  Premier League                   Everton  ...         Brighton     0.54
# 2021-08-14  Premier League              Leeds United  ...   Manchester Utd     0.31
# 2021-08-21  Premier League              Leeds United  ...          Everton     0.40
# 2021-08-29  Premier League              Leeds United  ...          Burnley     0.52
# 2021-09-12  Premier League              Leeds United  ...        Liverpool     0.23
# 2021-09-17  Premier League              Leeds United  ...    Newcastle Utd     0.65
# 2021-09-25  Premier League              Leeds United  ...         West Ham     0.40
# 2021-10-02  Premier League              Leeds United  ...          Watford     0.85
# 2021-10-16  Premier League              Leeds United  ...      Southampton     0.08
# 2021-10-23  Premier League              Leeds United  ...           Wolves     0.69
# 2021-10-31  Premier League              Leeds United  ...     Norwich City     0.52
# 2021-11-07  Premier League              Leeds United  ...   Leicester City     0.52
# 2021-11-21  Premier League              Leeds United  ...        Tottenham     0.31
# 2021-11-27  Premier League              Leeds United  ...         Brighton     0.25
# 2021-11-30  Premier League              Leeds United  ...   Crystal Palace     0.65
# 2021-12-05  Premier League              Leeds United  ...        Brentford     0.54
# 2021-12-11  Premier League              Leeds United  ...          Chelsea     0.27
# 2021-12-14  Premier League              Leeds United  ...  Manchester City     0.02
# 2021-12-18  Premier League              Leeds United  ...          Arsenal     0.31
# 2022-01-02  Premier League              Leeds United  ...          Burnley     0.62
# 2021-08-14  Premier League            Leicester City  ...           Wolves     0.44
# 2021-08-23  Premier League            Leicester City  ...         West Ham     0.15
# 2021-08-28  Premier League            Leicester City  ...     Norwich City     0.44
# 2021-09-11  Premier League            Leicester City  ...  Manchester City     0.15
# 2021-09-19  Premier League            Leicester City  ...         Brighton     0.56
# 2021-09-25  Premier League            Leicester City  ...          Burnley     0.88
# 2021-10-03  Premier League            Leicester City  ...   Crystal Palace     0.58
# 2021-10-16  Premier League            Leicester City  ...   Manchester Utd     0.73
# 2021-10-24  Premier League            Leicester City  ...        Brentford     0.56
# 2021-10-30  Premier League            Leicester City  ...          Arsenal     0.56
# 2021-11-07  Premier League            Leicester City  ...     Leeds United     0.48
# 2021-11-20  Premier League            Leicester City  ...          Chelsea     0.08
# 2021-11-28  Premier League            Leicester City  ...          Watford     0.44
# 2021-12-01  Premier League            Leicester City  ...      Southampton     0.50
# 2021-12-05  Premier League            Leicester City  ...      Aston Villa     0.38
# 2021-12-12  Premier League            Leicester City  ...    Newcastle Utd     0.90
# 2021-12-26  Premier League            Leicester City  ...  Manchester City     0.46
# 2021-12-28  Premier League            Leicester City  ...        Liverpool     0.10
# 2021-08-14  Premier League                 Liverpool  ...     Norwich City     0.62
# 2021-08-21  Premier League                 Liverpool  ...          Burnley     0.88
# 2021-08-28  Premier League                 Liverpool  ...          Chelsea     0.85
# 2021-09-12  Premier League                 Liverpool  ...     Leeds United     0.77
# 2021-09-18  Premier League                 Liverpool  ...   Crystal Palace     0.85
# 2021-09-25  Premier League                 Liverpool  ...        Brentford     0.62
# 2021-10-03  Premier League                 Liverpool  ...  Manchester City     0.46
# 2021-10-16  Premier League                 Liverpool  ...          Watford     0.92
# 2021-10-24  Premier League                 Liverpool  ...   Manchester Utd     0.71
# 2021-10-30  Premier League                 Liverpool  ...         Brighton     0.50
# 2021-11-07  Premier League                 Liverpool  ...         West Ham     0.58
# 2021-11-20  Premier League                 Liverpool  ...          Arsenal     0.94
# 2021-11-27  Premier League                 Liverpool  ...      Southampton     0.81
# 2021-12-01  Premier League                 Liverpool  ...          Everton     0.81
# 2021-12-04  Premier League                 Liverpool  ...           Wolves     0.98
# 2021-12-11  Premier League                 Liverpool  ...      Aston Villa     0.94
# 2021-12-16  Premier League                 Liverpool  ...    Newcastle Utd     0.94
# 2021-12-19  Premier League                 Liverpool  ...        Tottenham     0.29
# 2021-12-28  Premier League                 Liverpool  ...   Leicester City     0.90
# 2022-01-02  Premier League                 Liverpool  ...          Chelsea     0.50
# 2021-08-15  Premier League           Manchester City  ...        Tottenham     0.62
# 2021-08-21  Premier League           Manchester City  ...     Norwich City     1.00
# 2021-08-28  Premier League           Manchester City  ...          Arsenal     1.00
# 2021-09-11  Premier League           Manchester City  ...   Leicester City     0.85
# 2021-09-18  Premier League           Manchester City  ...      Southampton     0.65
# 2021-09-25  Premier League           Manchester City  ...          Chelsea     0.79
# 2021-10-03  Premier League           Manchester City  ...        Liverpool     0.54
# 2021-10-16  Premier League           Manchester City  ...          Burnley     0.69
# 2021-10-23  Premier League           Manchester City  ...         Brighton     0.75
# 2021-10-30  Premier League           Manchester City  ...   Crystal Palace     0.50
# 2021-11-06  Premier League           Manchester City  ...   Manchester Utd     0.79
# 2021-11-21  Premier League           Manchester City  ...          Everton     0.92
# 2021-11-28  Premier League           Manchester City  ...         West Ham     0.90
# 2021-12-01  Premier League           Manchester City  ...      Aston Villa     0.50
# 2021-12-04  Premier League           Manchester City  ...          Watford     0.88
# 2021-12-11  Premier League           Manchester City  ...           Wolves     0.98
# 2021-12-14  Premier League           Manchester City  ...     Leeds United     0.98
# 2021-12-19  Premier League           Manchester City  ...    Newcastle Utd     0.94
# 2021-12-26  Premier League           Manchester City  ...   Leicester City     0.54
# 2021-12-29  Premier League           Manchester City  ...        Brentford     0.60
# 2022-01-01  Premier League           Manchester City  ...          Arsenal     0.67
# 2021-08-14  Premier League         Manchester United  ...     Leeds United     0.69
# 2021-08-22  Premier League         Manchester United  ...      Southampton     0.62
# 2021-08-29  Premier League         Manchester United  ...           Wolves     0.25
# 2021-09-11  Premier League         Manchester United  ...    Newcastle Utd     0.79
# 2021-09-19  Premier League         Manchester United  ...         West Ham     0.54
# 2021-09-25  Premier League         Manchester United  ...      Aston Villa     0.73
# 2021-10-02  Premier League         Manchester United  ...          Everton     0.46
# 2021-10-16  Premier League         Manchester United  ...   Leicester City     0.27
# 2021-10-24  Premier League         Manchester United  ...        Liverpool     0.29
# 2021-10-30  Premier League         Manchester United  ...        Tottenham     0.60
# 2021-11-06  Premier League         Manchester United  ...  Manchester City     0.21
# 2021-11-20  Premier League         Manchester United  ...          Watford     0.38
# 2021-11-28  Premier League         Manchester United  ...          Chelsea     0.12
# 2021-12-02  Premier League         Manchester United  ...          Arsenal     0.58
# 2021-12-05  Premier League         Manchester United  ...   Crystal Palace     0.54
# 2021-12-11  Premier League         Manchester United  ...     Norwich City     0.71
# 2021-12-27  Premier League         Manchester United  ...    Newcastle Utd     0.52
# 2021-12-30  Premier League         Manchester United  ...          Burnley     0.75
# 2021-08-15  Premier League          Newcastle United  ...         West Ham     0.33
# 2021-08-21  Premier League          Newcastle United  ...      Aston Villa     0.42
# 2021-08-28  Premier League          Newcastle United  ...      Southampton     0.27
# 2021-09-11  Premier League          Newcastle United  ...   Manchester Utd     0.21
# 2021-09-17  Premier League          Newcastle United  ...     Leeds United     0.35
# 2021-09-25  Premier League          Newcastle United  ...          Watford     0.79
# 2021-10-02  Premier League          Newcastle United  ...           Wolves     0.44
# 2021-10-17  Premier League          Newcastle United  ...        Tottenham     0.27
# 2021-10-23  Premier League          Newcastle United  ...   Crystal Palace     0.23
# 2021-10-30  Premier League          Newcastle United  ...          Chelsea     0.12
# 2021-11-06  Premier League          Newcastle United  ...         Brighton     0.21
# 2021-11-20  Premier League          Newcastle United  ...        Brentford     0.67
# 2021-11-27  Premier League          Newcastle United  ...          Arsenal     0.12
# 2021-11-30  Premier League          Newcastle United  ...     Norwich City     0.44
# 2021-12-04  Premier League          Newcastle United  ...          Burnley     0.62
# 2021-12-12  Premier League          Newcastle United  ...   Leicester City     0.10
# 2021-12-16  Premier League          Newcastle United  ...        Liverpool     0.06
# 2021-12-19  Premier League          Newcastle United  ...  Manchester City     0.06
# 2021-12-27  Premier League          Newcastle United  ...   Manchester Utd     0.48
# 2021-08-14  Premier League              Norwich City  ...        Liverpool     0.38
# 2021-08-21  Premier League              Norwich City  ...  Manchester City     0.00
# 2021-08-28  Premier League              Norwich City  ...   Leicester City     0.56
# 2021-09-11  Premier League              Norwich City  ...          Arsenal     0.10
# 2021-09-18  Premier League              Norwich City  ...          Watford     0.33
# 2021-09-25  Premier League              Norwich City  ...          Everton     0.19
# 2021-10-02  Premier League              Norwich City  ...          Burnley     0.40
# 2021-10-16  Premier League              Norwich City  ...         Brighton     0.52
# 2021-10-23  Premier League              Norwich City  ...          Chelsea     0.02
# 2021-10-31  Premier League              Norwich City  ...     Leeds United     0.48
# 2021-11-06  Premier League              Norwich City  ...        Brentford     0.33
# 2021-11-20  Premier League              Norwich City  ...      Southampton     0.38
# 2021-11-27  Premier League              Norwich City  ...           Wolves     0.75
# 2021-11-30  Premier League              Norwich City  ...    Newcastle Utd     0.56
# 2021-12-05  Premier League              Norwich City  ...        Tottenham     0.48
# 2021-12-11  Premier League              Norwich City  ...   Manchester Utd     0.29
# 2021-12-14  Premier League              Norwich City  ...      Aston Villa     0.25
# 2021-12-26  Premier League              Norwich City  ...          Arsenal     0.00
# 2021-12-28  Premier League              Norwich City  ...   Crystal Palace     0.33
# 2021-08-14  Premier League               Southampton  ...          Everton     0.15
# 2021-08-22  Premier League               Southampton  ...   Manchester Utd     0.38
# 2021-08-28  Premier League               Southampton  ...    Newcastle Utd     0.73
# 2021-09-11  Premier League               Southampton  ...         West Ham     0.54
# 2021-09-18  Premier League               Southampton  ...  Manchester City     0.35
# 2021-09-26  Premier League               Southampton  ...           Wolves     0.54
# 2021-10-02  Premier League               Southampton  ...          Chelsea     0.25
# 2021-10-16  Premier League               Southampton  ...     Leeds United     0.92
# 2021-10-23  Premier League               Southampton  ...          Burnley     0.69
# 2021-10-30  Premier League               Southampton  ...          Watford     0.67
# 2021-11-05  Premier League               Southampton  ...      Aston Villa     0.54
# 2021-11-20  Premier League               Southampton  ...     Norwich City     0.62
# 2021-11-27  Premier League               Southampton  ...        Liverpool     0.19
# 2021-12-01  Premier League               Southampton  ...   Leicester City     0.50
# 2021-12-04  Premier League               Southampton  ...         Brighton     0.50
# 2021-12-11  Premier League               Southampton  ...          Arsenal     0.31
# 2021-12-15  Premier League               Southampton  ...   Crystal Palace     0.40
# 2021-12-26  Premier League               Southampton  ...         West Ham     0.42
# 2021-12-28  Premier League               Southampton  ...        Tottenham     0.08
# 2021-08-15  Premier League         Tottenham Hotspur  ...  Manchester City     0.38
# 2021-08-22  Premier League         Tottenham Hotspur  ...           Wolves     0.52
# 2021-08-29  Premier League         Tottenham Hotspur  ...          Watford     0.56
# 2021-09-11  Premier League         Tottenham Hotspur  ...   Crystal Palace     0.02
# 2021-09-19  Premier League         Tottenham Hotspur  ...          Chelsea     0.25
# 2021-09-26  Premier League         Tottenham Hotspur  ...          Arsenal     0.54
# 2021-10-03  Premier League         Tottenham Hotspur  ...      Aston Villa     0.62
# 2021-10-17  Premier League         Tottenham Hotspur  ...    Newcastle Utd     0.73
# 2021-10-24  Premier League         Tottenham Hotspur  ...         West Ham     0.40
# 2021-10-30  Premier League         Tottenham Hotspur  ...   Manchester Utd     0.40
# 2021-11-07  Premier League         Tottenham Hotspur  ...          Everton     0.56
# 2021-11-21  Premier League         Tottenham Hotspur  ...     Leeds United     0.69
# 2021-12-02  Premier League         Tottenham Hotspur  ...        Brentford     0.94
# 2021-12-05  Premier League         Tottenham Hotspur  ...     Norwich City     0.52
# 2021-12-19  Premier League         Tottenham Hotspur  ...        Liverpool     0.71
# 2021-12-26  Premier League         Tottenham Hotspur  ...   Crystal Palace     0.98
# 2021-12-28  Premier League         Tottenham Hotspur  ...      Southampton     0.92
# 2022-01-01  Premier League         Tottenham Hotspur  ...          Watford     0.85
# 2021-08-14  Premier League                   Watford  ...      Aston Villa     0.52
# 2021-08-21  Premier League                   Watford  ...         Brighton     0.38
# 2021-08-29  Premier League                   Watford  ...        Tottenham     0.44
# 2021-09-11  Premier League                   Watford  ...           Wolves     0.10
# 2021-09-18  Premier League                   Watford  ...     Norwich City     0.67
# 2021-09-25  Premier League                   Watford  ...    Newcastle Utd     0.21
# 2021-10-02  Premier League                   Watford  ...     Leeds United     0.15
# 2021-10-16  Premier League                   Watford  ...        Liverpool     0.08
# 2021-10-23  Premier League                   Watford  ...          Everton     0.54
# 2021-10-30  Premier League                   Watford  ...      Southampton     0.33
# 2021-11-07  Premier League                   Watford  ...          Arsenal     0.29
# 2021-11-20  Premier League                   Watford  ...   Manchester Utd     0.62
# 2021-11-28  Premier League                   Watford  ...   Leicester City     0.56
# 2021-12-01  Premier League                   Watford  ...          Chelsea     0.44
# 2021-12-04  Premier League                   Watford  ...  Manchester City     0.12
# 2021-12-10  Premier League                   Watford  ...        Brentford     0.23
# 2021-12-28  Premier League                   Watford  ...         West Ham     0.21
# 2022-01-01  Premier League                   Watford  ...        Tottenham     0.15
# 2021-08-15  Premier League           West Ham United  ...    Newcastle Utd     0.67
# 2021-08-23  Premier League           West Ham United  ...   Leicester City     0.85
# 2021-08-28  Premier League           West Ham United  ...   Crystal Palace     0.60
# 2021-09-11  Premier League           West Ham United  ...      Southampton     0.46
# 2021-09-19  Premier League           West Ham United  ...   Manchester Utd     0.46
# 2021-09-25  Premier League           West Ham United  ...     Leeds United     0.60
# 2021-10-03  Premier League           West Ham United  ...        Brentford     0.52
# 2021-10-17  Premier League           West Ham United  ...          Everton     0.65
# 2021-10-24  Premier League           West Ham United  ...        Tottenham     0.60
# 2021-10-31  Premier League           West Ham United  ...      Aston Villa     0.83
# 2021-11-07  Premier League           West Ham United  ...        Liverpool     0.42
# 2021-11-20  Premier League           West Ham United  ...           Wolves     0.35
# 2021-11-28  Premier League           West Ham United  ...  Manchester City     0.10
# 2021-12-01  Premier League           West Ham United  ...         Brighton     0.60
# 2021-12-04  Premier League           West Ham United  ...          Chelsea     0.62
# 2021-12-12  Premier League           West Ham United  ...          Burnley     0.48
# 2021-12-15  Premier League           West Ham United  ...          Arsenal     0.04
# 2021-12-26  Premier League           West Ham United  ...      Southampton     0.58
# 2021-12-28  Premier League           West Ham United  ...          Watford     0.79
# 2022-01-01  Premier League           West Ham United  ...   Crystal Palace     0.46
# 2021-08-14  Premier League   Wolverhampton Wanderers  ...   Leicester City     0.56
# 2021-08-22  Premier League   Wolverhampton Wanderers  ...        Tottenham     0.48
# 2021-08-29  Premier League   Wolverhampton Wanderers  ...   Manchester Utd     0.75
# 2021-09-11  Premier League   Wolverhampton Wanderers  ...          Watford     0.90
# 2021-09-18  Premier League   Wolverhampton Wanderers  ...        Brentford     0.10
# 2021-09-26  Premier League   Wolverhampton Wanderers  ...      Southampton     0.46
# 2021-10-02  Premier League   Wolverhampton Wanderers  ...    Newcastle Utd     0.56
# 2021-10-16  Premier League   Wolverhampton Wanderers  ...      Aston Villa     0.69
# 2021-10-23  Premier League   Wolverhampton Wanderers  ...     Leeds United     0.31
# 2021-11-01  Premier League   Wolverhampton Wanderers  ...          Everton     0.52
# 2021-11-06  Premier League   Wolverhampton Wanderers  ...   Crystal Palace     0.12
# 2021-11-20  Premier League   Wolverhampton Wanderers  ...         West Ham     0.65
# 2021-11-27  Premier League   Wolverhampton Wanderers  ...     Norwich City     0.25
# 2021-12-01  Premier League   Wolverhampton Wanderers  ...          Burnley     0.60
# 2021-12-04  Premier League   Wolverhampton Wanderers  ...        Liverpool     0.02
# 2021-12-11  Premier League   Wolverhampton Wanderers  ...  Manchester City     0.02
# 2021-12-15  Premier League   Wolverhampton Wanderers  ...         Brighton     0.54
# 2021-12-19  Premier League   Wolverhampton Wanderers  ...          Chelsea     0.40
#
# [380 rows x 10 columns]

# %%
home_agg = aggregate_df[aggregate_df.venue == "Home"].groupby("team").mean().round(2)
away_agg = aggregate_df[aggregate_df.venue == "Away"].groupby("team").mean().round(2)

# %%
team_strength = dict()
for team, ids in pl_team_map.items():
    team = team.replace("-", " ")
    fpl_id = ids["fpl_id"]
    team_strength[fpl_id] = dict()
    team_strength[fpl_id]["home"] = {
        "attack": away_agg.loc[team].xg_for,
        "defense": away_agg.loc[team].xg_against
    }
    team_strength[fpl_id]["away"] = {
        "attack": home_agg.loc[team].xg_for,
        "defense": home_agg.loc[team].xg_against
    }

# %%
with open("xg_diff_team_strength", 'w+') as f:
    f.write(json.dumps(team_strength))

# %%
json.dumps(team_strength)
# Out:
# '{"1": {"home": {"attack": 0.47, "defense": 0.42}, "away": {"attack": 0.63, "defense": 0.62}}, "2": {"home": {"attack": 0.4, "defense": 0.45}, "away": {"attack": 0.37, "defense": 0.49}}, "3": {"home": {"attack": 0.39, "defense": 0.51}, "away": {"attack": 0.5, "defense": 0.59}}, "4": {"home": {"attack": 0.35, "defense": 0.56}, "away": {"attack": 0.53, "defense": 0.56}}, "5": {"home": {"attack": 0.3, "defense": 0.31}, "away": {"attack": 0.49, "defense": 0.58}}, "6": {"home": {"attack": 0.62, "defense": 0.65}, "away": {"attack": 0.69, "defense": 0.64}}, "7": {"home": {"attack": 0.32, "defense": 0.41}, "away": {"attack": 0.61, "defense": 0.68}}, "8": {"home": {"attack": 0.41, "defense": 0.4}, "away": {"attack": 0.55, "defense": 0.48}}, "10": {"home": {"attack": 0.37, "defense": 0.28}, "away": {"attack": 0.59, "defense": 0.45}}, "9": {"home": {"attack": 0.57, "defense": 0.34}, "away": {"attack": 0.58, "defense": 0.37}}, "11": {"home": {"attack": 0.84, "defense": 0.56}, "away": {"attack": 0.86, "defense": 0.73}}, "12": {"home": {"attack": 0.73, "defense": 0.72}, "away": {"attack": 0.83, "defense": 0.8}}, "13": {"home": {"attack": 0.5, "defense": 0.39}, "away": {"attack": 0.6, "defense": 0.52}}, "14": {"home": {"attack": 0.25, "defense": 0.33}, "away": {"attack": 0.4, "defense": 0.33}}, "15": {"home": {"attack": 0.31, "defense": 0.23}, "away": {"attack": 0.35, "defense": 0.44}}, "16": {"home": {"attack": 0.44, "defense": 0.37}, "away": {"attack": 0.45, "defense": 0.59}}, "17": {"home": {"attack": 0.48, "defense": 0.65}, "away": {"attack": 0.64, "defense": 0.57}}, "18": {"home": {"attack": 0.47, "defense": 0.34}, "away": {"attack": 0.36, "defense": 0.2}}, "19": {"home": {"attack": 0.51, "defense": 0.48}, "away": {"attack": 0.6, "defense": 0.57}}, "20": {"home": {"attack": 0.38, "defense": 0.47}, "away": {"attack": 0.36, "defense": 0.55}}}'
